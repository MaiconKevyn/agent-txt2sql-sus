# %%
import pandas as pd

df=pd.read_csv('data/dados_sus3.csv')
df
# Out:
# /tmp/ipykernel_19040/387095770.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('data/dados_sus3.csv')
#        DIAG_PRINC  MUNIC_RES  MUNIC_MOV   PROC_REA  IDADE  SEXO CID_MORTE  \
# 0            A46      430300     430300  303080078     67     3         0
# 1            C168     430300     430300  304100021     60     1         0
# 2            J128     430300     430300  303140151     76     3         0
# 3            I500     430300     430300  303060212     62     1         0
# 4            I158     430300     430300  303060107     29     3         0
# ...           ...        ...        ...        ...    ...   ...       ...
# 185293       I64      354780     430460  303040149     64     1
# 185294       S663     431337     430460  408060484     44     1
# 185295       M502     430460     430460  408030445     76     3
# 185296       S860     412550     430460  408060476     32     1
# ...

# %%
df.CIDADE_RESIDENCIA_PACIENTE.value_counts()
# Out:
# CIDADE_RESIDENCIA_PACIENTE
# Uruguaiana        9288
# Ijuí              8809
# Passo Fundo       8787
# Porto Alegre      7036
# Caxias do Sul     6825
#                   ...
# Marabá               1
# Uberaba              1
# Rio Verde            1
# Campina Grande       1
# Parnaíba             1
# Name: count, Length: 102, dtype: int64

# %%
df
# Out:
#        DIAG_PRINC  MUNIC_RES  MUNIC_MOV   PROC_REA  IDADE  SEXO CID_MORTE  \
# 0            A46      430300     430300  303080078     67     3         0
# 1            C168     430300     430300  304100021     60     1         0
# 2            J128     430300     430300  303140151     76     3         0
# 3            I500     430300     430300  303060212     62     1         0
# 4            I158     430300     430300  303060107     29     3         0
# ...           ...        ...        ...        ...    ...   ...       ...
# 185293       I64      354780     430460  303040149     64     1
# 185294       S663     431337     430460  408060484     44     1
# 185295       M502     430460     430460  408030445     76     3
# 185296       S860     412550     430460  408060476     32     1
# 185297       S628     431337     430460  408020172      6     3
#
#         MORTE     CNES  VAL_TOT  UTI_MES_TO  DT_INTER  DT_SAIDA  \
# ...

# %%
# Contagem de registros com sexo=3 e idade>50
filtro = (df['SEXO'] == 3) & (df['IDADE'] > 20) & (df['MORTE'] == 1)

print(f"Total de pacientes com sexo=3 e idade>50: {total_sexo3_idade_maior50}")

# Visualizando os dados filtrados
df_filtrado = df[filtro]
df_filtrado
# Out:
# Total de pacientes com sexo=3 e idade>50: 0
#        DIAG_PRINC  MUNIC_RES  MUNIC_MOV   PROC_REA  IDADE  SEXO CID_MORTE  \
# 2            J128     430300     430300  303140151     76     3         0
# 24           R579     430300     430300  303060077     75     3         0
# 45           E105     430513     430300  303060131     49     3         0
# 83           A310     432070     430300  303010037     68     3         0
# 95           K564     430300     430300  407020101     86     3         0
# ...           ...        ...        ...        ...    ...   ...       ...
# 184842       I702     430258     431020  303060204     87     3      0000
# 184860       C710     432110     431560  403030030     43     3      0000
# 184880       L89      430130     430130  303080094     75     3      0000
# 185068       I702     431980     431690  406020345     65     3      0000
# 185245       K631     430770     430770  407020098     85     3      0000
#
# ...

# %%
df_filtrado
# Out:
#        DIAG_PRINC  MUNIC_RES  MUNIC_MOV   PROC_REA  IDADE  SEXO CID_MORTE  \
# 0            A46      430300     430300  303080078     67     3         0
# 2            J128     430300     430300  303140151     76     3         0
# 9            T846     430300     430300  408060352     66     3         0
# 11           C56      430300     430300  406020078     62     3         0
# 12           C448     430300     430300  416080030     52     3         0
# ...           ...        ...        ...        ...    ...   ...       ...
# 185263       C329     430975     430300  416030297     62     3
# 185271       K429     430460     430460  407040153     67     3
# 185285       T848     431337     430460  408060387     67     3
# 185291       S424     431405     430460  408020350     57     3
# 185295       M502     430460     430460  408030445     76     3
#
#         MORTE     CNES  VAL_TOT  UTI_MES_TO  DT_INTER  DT_SAIDA  \
# ...
